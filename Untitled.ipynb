# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
df=pd.read_csv("Resources\\Project2_idmc_disaster_all_dataset.csv")

# %%
df.head()
# Out:
#   Country code Country Name  Year Start Date  \
# 0          AB9   Abyei Area  2018   7/1/2018
# 1          AB9   Abyei Area  2019   6/1/2019
# 2          AFG  Afghanistan  2008   1/1/2008
# 3          AFG  Afghanistan  2008  4/17/2008
# 4          AFG  Afghanistan  2008   8/1/2008
#
#                                    Event Name  Hazard Category  \
# 0                   Abyie: Flood - 01/07/2018  Weather related
# 1  Abyei: Flood - southern parts - 01/06/2019  Weather related
# 2                                         NaN  Weather related
# 3                                         NaN      Geophysical
# 4                                         NaN  Weather related
#
#            Hazard Type  New Displacements
# 0                Flood                2.0
# 1                Flood            40000.0
# 2  Extreme temperature                NaN
# 3           Earthquake             3250.0
# 4                Flood              180.0

# %%
# !pip install pycountry_convert
# Out:
# Requirement already satisfied: pycountry_convert in c:\users\mamec\anaconda3\lib\site-packages (0.7.2)
# Requirement already satisfied: pytest-mock>=1.6.3 in c:\users\mamec\anaconda3\lib\site-packages (from pycountry_convert) (3.3.1)
# Requirement already satisfied: pytest>=3.4.0 in c:\users\mamec\anaconda3\lib\site-packages (from pycountry_convert) (5.3.5)
# Requirement already satisfied: pytest-cov>=2.5.1 in c:\users\mamec\anaconda3\lib\site-packages (from pycountry_convert) (2.10.1)
# Requirement already satisfied: pprintpp>=0.3.0 in c:\users\mamec\anaconda3\lib\site-packages (from pycountry_convert) (0.4.0)
# Requirement already satisfied: repoze.lru>=0.7 in c:\users\mamec\anaconda3\lib\site-packages (from pycountry_convert) (0.7)
# Requirement already satisfied: pycountry>=16.11.27.1 in c:\users\mamec\anaconda3\lib\site-packages (from pycountry_convert) (20.7.3)
# Requirement already satisfied: wheel>=0.30.0 in c:\users\mamec\anaconda3\lib\site-packages (from pycountry_convert) (0.34.2)
# Requirement already satisfied: py>=1.5.0 in c:\users\mamec\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.8.1)
# Requirement already satisfied: packaging in c:\users\mamec\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (20.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mamec\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (19.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\users\mamec\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (8.2.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\users\mamec\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (0.13.1)
# Requirement already satisfied: wcwidth in c:\users\mamec\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (0.1.8)
# Requirement already satisfied: importlib-metadata>=0.12 in c:\users\mamec\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.5.0)
# Requirement already satisfied: atomicwrites>=1.0 in c:\users\mamec\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (1.3.0)
# Requirement already satisfied: colorama in c:\users\mamec\anaconda3\lib\site-packages (from pytest>=3.4.0->pycountry_convert) (0.4.3)
# Requirement already satisfied: coverage>=4.4 in c:\users\mamec\anaconda3\lib\site-packages (from pytest-cov>=2.5.1->pycountry_convert) (5.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\mamec\anaconda3\lib\site-packages (from packaging->pytest>=3.4.0->pycountry_convert) (2.4.6)
# Requirement already satisfied: six in c:\users\mamec\anaconda3\lib\site-packages (from packaging->pytest>=3.4.0->pycountry_convert) (1.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\mamec\anaconda3\lib\site-packages (from importlib-metadata>=0.12->pytest>=3.4.0->pycountry_convert) (2.2.0)

# %%
import pycountry_convert as pc

# %%
country_code = pc.country_name_to_country_alpha2("China", cn_name_format="default")
print(country_code)
continent_name = pc.country_alpha2_to_continent_code(country_code)
print(continent_name)
# Out:
# CN
# AS

# %%
#df[continent]= pc.country_alpha2_to_continent_code(country_code).(df["Country Name"])

# %%
def country_code(name):
    try:
        code = pc.country_name_to_country_alpha2(name, cn_name_format="default")
        return code
    except:
        return "N/A"
def continent_name(name):
    try:
        continent = pc.country_alpha2_to_continent_code(name)
        return continent
    except:
        return "N/A"
df["Country_2D"] = df["Country Name"].apply(country_code)
df["Continent"] = df["Country_2D"].apply(continent_name)

# %%
df.head()
# Out:
#   Country code Country Name  Year Start Date  \
# 0          AB9   Abyei Area  2018   7/1/2018
# 1          AB9   Abyei Area  2019   6/1/2019
# 2          AFG  Afghanistan  2008   1/1/2008
# 3          AFG  Afghanistan  2008  4/17/2008
# 4          AFG  Afghanistan  2008   8/1/2008
#
#                                    Event Name  Hazard Category  \
# 0                   Abyie: Flood - 01/07/2018  Weather related
# 1  Abyei: Flood - southern parts - 01/06/2019  Weather related
# 2                                         NaN  Weather related
# 3                                         NaN      Geophysical
# 4                                         NaN  Weather related
#
#            Hazard Type  New Displacements Country_2D Continent
# 0                Flood                2.0        N/A       N/A
# 1                Flood            40000.0        N/A       N/A
# 2  Extreme temperature                NaN         AF        AS
# 3           Earthquake             3250.0         AF        AS
# 4                Flood              180.0         AF        AS

# %%
df_Africa= df[df["Continent"]=="AF"]

# %%
df_Africa
# Out:
#      Country code Country Name  Year Start Date  \
# 212           AGO       Angola  2009   1/1/2009
# 213           AGO       Angola  2009   1/1/2009
# 214           AGO       Angola  2009   1/1/2009
# 215           AGO       Angola  2010   1/1/2010
# 216           AGO       Angola  2010   1/1/2010
# ...           ...          ...   ...        ...
# 8354          ZWE     Zimbabwe  2018   1/1/2018
# 8355          ZWE     Zimbabwe  2019   3/4/2019
# 8356          ZWE     Zimbabwe  2019  2/13/2019
# 8357          ZWE     Zimbabwe  2019  10/7/2019
# 8358          ZWE     Zimbabwe  2019  1/11/2019
#
#                                              Event Name  Hazard Category  \
# 212                                                 NaN  Weather related
# 213                                                 NaN  Weather related
# 214                                                 NaN  Weather related
# 215                                                 NaN  Weather related
# 216                                                 NaN  Weather related
# ...                                                 ...              ...
# 8354          Zimbabwe: Hailstorm - Umguza - 01/01/2018  Weather related
# 8355  Malawi, Mozambique, Madagascar, Zimbabwe: Cycl...  Weather related
# 8356  Zimbabwe: Floods- Chiredzi (Masvingo)- 13/02/2019  Weather related
# 8357   Zimbabwe: Hailstorm- Masvingo (Zaka)- 07/10/2019  Weather related
# 8358            Zimbabwe: Storm - Masvingo - 11/01/2019  Weather related
#
#      Hazard Type  New Displacements Country_2D Continent
# 212        Flood              415.0         AO        AF
# 213        Flood             4650.0         AO        AF
# 214        Flood            81000.0         AO        AF
# 215        Flood             3875.0         AO        AF
# 216        Flood            75000.0         AO        AF
# ...          ...                ...        ...       ...
# 8354       Storm               80.0         ZW        AF
# 8355       Storm            50905.0         ZW        AF
# 8356       Flood              200.0         ZW        AF
# 8357       Storm              400.0         ZW        AF
# 8358       Storm              800.0         ZW        AF
#
# [1059 rows x 10 columns]

# %%
df.groupby("Continent").count()
# Out:
#            Country code  Country Name  Year  Start Date  Event Name  \
# Continent
# AF                 1059          1059  1059        1059         828
# AS                 3814          3814  3814        3814        3385
# EU                  517           517   517         517         394
# N/A                 453           453   453         453         393
# NA                 1251          1251  1251        1251        1067
# OC                  292           292   292         292         230
# SA                  973           973   973         973         860
#
#            Hazard Category  Hazard Type  New Displacements  Country_2D
# Continent
# AF                    1059         1059                990        1059
# AS                    3813         3813               3632        3814
# EU                     517          517                425         517
# N/A                    453          453                419         453
# NA                    1250         1250               1134        1251
# OC                     292          292                246         292
# SA                     972          972                924         973

# %%
# Create Postgres Engine
engine = create_engine ('postgres://postgres:Borice@88@localhost:5432/Bootcamp_Project_2')

# %%
df_Africa.to_sql ('Africa_Migration', con = engine, index_label = 'Africa_Migration_id')
